# %%
# Code to import libraries
import pandas as pd
dataframe=pd.read_excel("sample_data/Female and Male Astronauts Accepted in the NASA Program.xlsx")

# %%
# Delection of column ID
dataframe=dataframe.drop(dataframe.columns[[0]],axis=1)
dataframe
# Out:
#     Cohort   Year  Males Accepted in NASA Program   \
# 0         1  1959                              100
# 1         2  1962                              100
# 2         3  1963                              100
# 3         4  1965                              100
# 4         5  1966                              100
# 5         6  1967                              100
# 6         7  1969                              100
# 7         8  1978                               83
# 8         9  1980                               89
# 9        10  1984                               83
# 10       11  1985                               85
# 11       12  1987                               87
# 12       13  1990                               78
# 13       14  1992                               84
# 14       15  1995                               74
# 15       16  1996                               77
# 16       17  1998                               88
# ...

# %%
# Printing column names
list(dataframe.columns.values)
# Out:
# ['ID ',
#  'Cohort ',
#  'Year',
#  'Males Accepted in NASA Program ',
#  'Females Accepted in NASA Program ']

# %%
# Checking for NA in dataset
dataframe.isna()
# Out:
#      ID   Cohort    Year  Males Accepted in NASA Program   \
# 0   True    False  False                            False
# 1   True    False  False                            False
# 2   True    False  False                            False
# 3   True    False  False                            False
# 4   True    False  False                            False
# 5   True    False  False                            False
# 6   True    False  False                            False
# 7   True    False  False                            False
# 8   True    False  False                            False
# 9   True    False  False                            False
# 10  True    False  False                            False
# 11  True    False  False                            False
# 12  True    False  False                            False
# 13  True    False  False                            False
# 14  True    False  False                            False
# ...

# %%
# Getting the count of missing data
dataframe.isna().sum()
# Out:
# ID                                   27
# Cohort                                0
# Year                                  0
# Males Accepted in NASA Program        0
# Females Accepted in NASA Program      0
# dtype: int64

# %%
# Counting Males and Females in the column count
dataframe["count"]=dataframe['Males Accepted in NASA Program ']+dataframe['Females Accepted in NASA Program ']

# %%
# Printing the data
dataframe
# Out:
#     ID   Cohort   Year  Males Accepted in NASA Program   \
# 0   NaN        1  1959                              100
# 1   NaN        2  1962                              100
# 2   NaN        3  1963                              100
# 3   NaN        4  1965                              100
# 4   NaN        5  1966                              100
# 5   NaN        6  1967                              100
# 6   NaN        7  1969                              100
# 7   NaN        8  1978                               83
# 8   NaN        9  1980                               89
# 9   NaN       10  1984                               83
# 10  NaN       11  1985                               85
# 11  NaN       12  1987                               87
# 12  NaN       13  1990                               78
# 13  NaN       14  1992                               84
# 14  NaN       15  1995                               74
# 15  NaN       16  1996                               77
# ...

# %%
# Creating a new dataframe before the year 2017
newdataframe=dataframe[dataframe["Year"]<=2017]

# %%
# Creating a new dataframe after the year 1990
newdataframe=newdataframe[newdataframe["Year"]>=1990]
newdataframe
# Out:
#     ID   Cohort   Year  Males Accepted in NASA Program   \
# 12  NaN       13  1990                               78
# 13  NaN       14  1992                               84
# 14  NaN       15  1995                               74
# 15  NaN       16  1996                               77
# 16  NaN       17  1998                               88
# 17  NaN       18  2000                               82
# 18  NaN       19  2004                               82
# 19  NaN       20  2009                               67
# 20  NaN       21  2013                               50
# 21  NaN       22  2017                               55
#
#     Females Accepted in NASA Program   count
# 12                                 22    100
# 13                                 16    100
# 14                                 26    100
# 15                                 23    100
# 16                                 12    100
# 17                                 18    100
# ...

# %%
# Histogram plot for Females Accepted in NASA Program
import matplotlib.pyplot as plt
plt.hist(newdataframe['Females Accepted in NASA Program '])
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("Females Accepted in NASA Program histogram")
# Out:
# Text(0.5, 1.0, 'Females Accepted in NASA Program histogram')

# %%
# Histogram plot for Males Accepted in NASA Program
plt.hist(newdataframe['Males Accepted in NASA Program '])
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("Males Accepted in NASA Program histogram")
# Out:
# Text(0.5, 1.0, 'Males Accepted in NASA Program histogram')

# %%
#Bar plot for the the Males and Females Accepted in the NASA Program 
plt.bar(newdataframe['Year'],newdataframe['Males Accepted in NASA Program '],label="Males")
plt.bar(newdataframe['Year'],newdataframe['Females Accepted in NASA Program '],label="Females")
plt.xlabel("Year")
plt.ylabel("count")
plt.title("Males and Females Accepted in NASA Program histogram")
plt.legend()

# %%
#Correlation Matrix 
import seaborn as sns
a=sns.heatmap(dataframe.corr())
a.set(xlabel=("Acceptance into NASA program"),ylabel=("Acceptance into NASA Program"),title="correlation matrix of NASA Program Data")
# Out:
# [Text(32.999999999999986, 0.5, 'Acceptance into NASA Program'),
#  Text(0.5, 15.0, 'Acceptance into NASA program'),
#  Text(0.5, 1.0, 'correlation matrix of NASA Program Data')]

# %%
#Summary of the data
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 0 non-null      float64
#  1   Cohort                             27 non-null     int64
#  2   Year                               27 non-null     int64
#  3   Males Accepted in NASA Program     27 non-null     int64
#  4   Females Accepted in NASA Program   27 non-null     int64
#  5   count                              27 non-null     int64
# dtypes: float64(1), int64(5)
# memory usage: 1.4 KB

# %%
# The Mean of the data
dataframe.mean()
# Out:
# ID                                           NaN
# Cohort                                 14.000000
# Year                                 1991.814815
# Males Accepted in NASA Program         69.037037
# Females Accepted in NASA Program       12.444444
# count                                  81.481481
# dtype: float64

# %%
#The Median of the data
dataframe.median()
# Out:
# ID                                      NaN
# Cohort                                 14.0
# Year                                 1992.0
# Males Accepted in NASA Program         83.0
# Females Accepted in NASA Program       12.0
# count                                 100.0
# dtype: float64

# %%
# The standarad deviation of the data
dataframe.std()
# Out:
# ID                                         NaN
# Cohort                                7.937254
# Year                                 20.961571
# Males Accepted in NASA Program       35.926722
# Females Accepted in NASA Program     14.227096
# count                                39.584739
# dtype: float64

# %%
# The 75% quantile of the data
dataframe.quantile(q=.75)
# Out:
# ID                                      NaN
# Cohort                                 20.5
# Year                                 2011.0
# Males Accepted in NASA Program         94.5
# Females Accepted in NASA Program       18.0
# count                                 100.0
# Name: 0.75, dtype: float64

# %% [markdown]
# The data is taken from year 1959 to 2022, it gives the details of males and females accepted in the NASA program. Until 1969 there was no females admitted in the NASA program; after 2017 there was no admission to the NASA program which admits astronauts within a 2 to 3 year period but due to onset of COVID there are no record admissions into the NASA program. The overall admission into NASA is 100 every year.Males were expected more until 2010 but after 2010 Females were accepted more frequently. In 2011 Males were accpeted 95% of the time compared to females.

# %%
# Single Sample t-test for Males
import scipy.stats as stats
#perform one sample t-test
stats.ttest_1samp(a=dataframe['Males Accepted in NASA Program '], popmean=50)
# Out:
# Ttest_1sampResult(statistic=2.7533640966067994, pvalue=0.010615850040028438)

# %% [markdown]
# 1. The null hypothesis, mean = 50
# 2. Aletrnate hypothesis, the mean is not equal to 50
# Results: The p-value is less than 0.05 and the null hypothesis is rejected and the alternate hypothesis is correct.

# %%
# Single Sample t-test for Females
import scipy.stats as stats
#perform one sample t-test
stats.ttest_1samp(a=dataframe['Females Accepted in NASA Program '], popmean=50)
# Out:
# Ttest_1sampResult(statistic=-13.716389697693476, pvalue=2.0505325124788425e-13)

# %% [markdown]
# 1. The null hypothesis , mean = 50
# 2. Alternaye hypothesis , the mean is not equal to 50 results. The p-value is less than 0.05 and the null hypothesis is rejected and the alternate hypothesis is correct.

# %%
#Independent T-Test
from scipy import stats
from scipy.stats import ttest_ind
ttest_ind(dataframe['Females Accepted in NASA Program ']
, dataframe['Males Accepted in NASA Program '])
# Out:
# Ttest_indResult(statistic=-7.610115797517843, pvalue=5.281467527068827e-10)

# %% [markdown]
# The null hypothesis, both the means are equal and the alternate hypothesis the means are not equal. The results since the p-value is less than 0.05 the null hypothesis is rejected and the aternate hypothesis is accepted. The two columns is independent.

# %%
#Correlation Tables 
dataframe.corr(method='pearson')
# Out:
#                                    ID    Cohort       Year  \
# ID                                 NaN       NaN       NaN
# Cohort                             NaN  1.000000  0.994496
# Year                               NaN  0.994496  1.000000
# Males Accepted in NASA Program     NaN -0.857819 -0.856626
# Females Accepted in NASA Program   NaN  0.292913  0.345667
# count                              NaN -0.673273 -0.653230
#
#                                    Males Accepted in NASA Program   \
# ID                                                             NaN
# Cohort                                                   -0.857819
# Year                                                     -0.856626
# Males Accepted in NASA Program                            1.000000
# Females Accepted in NASA Program                          0.072204
# count                                                     0.933541
#
# ...

# %%
#Correlation Plot 
sns.heatmap(dataframe.corr(), annot=True)

# %% [markdown]
# The year and males inversely correlated; as the years increases the males count decreases.

# %%
#Linear Regression of Males by Year
# %matplotlib inline
import  statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox
x = dataframe['Males Accepted in NASA Program ']
y = dataframe['Year']
model = sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Year   R-squared (uncentered):                   0.786
# Model:                            OLS   Adj. R-squared (uncentered):              0.778
# Method:                 Least Squares   F-statistic:                              95.45
# Date:                Fri, 13 May 2022   Prob (F-statistic):                    3.43e-10
# Time:                        23:02:33   Log-Likelihood:                         -222.62
# No. Observations:                  27   AIC:                                      447.2
# Df Residuals:                      26   BIC:                                      448.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# The R-square values shows that males count is dependent on year. Higher the R-square valur the higher the correlation.

# %%
# Linear Regression of Females by Year
# %matplotlib inline
import  statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox
x = dataframe['Females Accepted in NASA Program ']
y = dataframe['Year']
model = sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Year   R-squared (uncentered):                   0.446
# Model:                            OLS   Adj. R-squared (uncentered):              0.425
# Method:                 Least Squares   F-statistic:                              20.95
# Date:                Fri, 13 May 2022   Prob (F-statistic):                    0.000103
# Time:                        23:06:12   Log-Likelihood:                         -235.45
# No. Observations:                  27   AIC:                                      472.9
# Df Residuals:                      26   BIC:                                      474.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# The R-square shows that the year and females are not correlated; as the value is 0.4 which is far from 1, which is a weak correlation .
